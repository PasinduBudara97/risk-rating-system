# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("info.csv")

# %%
data.head(20)
# Out:
#     Loan No    Loan amount   Period          EMI            Purpose of loan  \
# 0         1     500,000.00      120    9,497.61                   Purchase
# 1         2     400,000.00      120    6,825.68                Construction
# 2         3     100,000.00       60    2,512.22                       OTHER
# 3         4     132,000.00       60    3,316.13                       OTHER
# 4         5     146,000.00       60    3,667.84                       OTHER
# 5         6     550,000.00      120    7,384.53                Construction
# 6         7     936,000.00      126   10,030.61   Redemption & Construction
# 7         8     500,000.00       60   12,561.11                  Furnitures
# 8         9      91,000.00      120    1,610.50                       OTHER
# 9        10     500,000.00       84   10,073.94                Construction
# 10       11     275,000.00       84    5,506.01                       OTHER
# ...

# %%
data.shape
# Out:
# (15690, 20)

# %%
data.describe()
# Out:
#             Loan No        Period  purpose of loan score  Unnamed: 6  \
# count  15690.000000  15690.000000             692.000000         0.0
# mean    7845.500000     92.823709              35.476879         NaN
# std     4529.457197     42.959331              11.126339         NaN
# min        1.000000      2.000000              10.000000         NaN
# 25%     3923.250000     60.000000              20.000000         NaN
# 50%     7845.500000     84.000000              40.000000         NaN
# 75%    11767.750000    120.000000              40.000000         NaN
# max    15690.000000    360.000000              60.000000         NaN
#
#        Unnamed: 7  Unnamed: 9  Unnamed: 11  Unnamed: 13  \
# count         0.0         0.0          0.0          0.0
# mean          NaN         NaN          NaN          NaN
# std           NaN         NaN          NaN          NaN
# min           NaN         NaN          NaN          NaN
# 25%           NaN         NaN          NaN          NaN
# ...

# %%
data.hist()
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>
